# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def plot_file(name):
    basic = pd.read_csv(name)
    basic['sum'] = basic.iloc[:, 2:].sum(axis=1)
    basic = basic[['month', 'year', 'sum']]
    yearly_notnorm = basic[['year', 'sum']].groupby('year').sum()
    yearly_notnorm.plot()

# %%
plot_file('countries-text.csv')

# %%
plot_file('countries-titles.csv')

# %%
plot_file('countries-text-normalized.csv')

# %%
plot_file('countries-titles-normalized.csv')
